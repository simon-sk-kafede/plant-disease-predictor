# %% [markdown]
# Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os
import pickle

# %% [markdown]
# image processing

# %%
# Set paths
train_dir = "train"
valid_dir = "valid"

# Parameters
img_size = (224, 224)
batch_size = 16
num_classes = len(os.listdir(train_dir))  # Automatically count classes
print("Number of classes:", num_classes)
# Out:
# Number of classes: 12

# %%
# Data Augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 91 images belonging to 12 classes.
# Found 91 images belonging to 12 classes.

# %% [markdown]
# ..................

# %%
# Build Model with MobileNetV2
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze base

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
output = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
# Compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Callbacks
callbacks = [
    EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)
]

# %%
# Train
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=30,
    callbacks=callbacks
)
# Out:
# c:\Users\ikaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.1079 - loss: 3.2934 - val_accuracy: 0.3516 - val_loss: 1.9584 - learning_rate: 0.0010
# Epoch 2/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.3502 - loss: 2.2254 - val_accuracy: 0.5495 - val_loss: 1.4418 - learning_rate: 0.0010
# Epoch 3/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5066 - loss: 1.6921 - val_accuracy: 0.6593 - val_loss: 1.1371 - learning_rate: 0.0010
# Epoch 4/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.4893 - loss: 1.5010 - val_accuracy: 0.7473 - val_loss: 0.9212 - learning_rate: 0.0010
# Epoch 5/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5701 - loss: 1.2444 - val_accuracy: 0.8022 - val_loss: 0.7348 - learning_rate: 0.0010
# Epoch 6/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.6589 - loss: 0.9501 - val_accuracy: 0.8352 - val_loss: 0.5898 - learning_rate: 0.0010
# Epoch 7/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.6938 - loss: 0.8895 - val_accuracy: 0.9231 - val_loss: 0.4290 - learning_rate: 0.0010
# Epoch 8/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.7450 - loss: 0.7022 - val_accuracy: 0.9341 - val_loss: 0.3438 - learning_rate: 0.0010
# Epoch 9/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.6378 - loss: 0.7857 - val_accuracy: 0.9451 - val_loss: 0.2905 - learning_rate: 0.0010
# Epoch 10/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.7670 - loss: 0.5725 - val_accuracy: 0.9560 - val_loss: 0.2540 - learning_rate: 0.0010
# Epoch 11/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8166 - loss: 0.4711 - val_accuracy: 0.9560 - val_loss: 0.2324 - learning_rate: 0.0010
# Epoch 12/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.8966 - loss: 0.3904 - val_accuracy: 0.9560 - val_loss: 0.2325 - learning_rate: 0.0010
# Epoch 13/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8900 - loss: 0.4175 - val_accuracy: 0.9670 - val_loss: 0.1943 - learning_rate: 0.0010
# Epoch 14/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9101 - loss: 0.3541 - val_accuracy: 0.9670 - val_loss: 0.1625 - learning_rate: 0.0010
# Epoch 15/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8940 - loss: 0.3363 - val_accuracy: 0.9670 - val_loss: 0.1434 - learning_rate: 0.0010
# Epoch 16/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8904 - loss: 0.3223 - val_accuracy: 0.9670 - val_loss: 0.1340 - learning_rate: 0.0010
# Epoch 17/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9074 - loss: 0.2467 - val_accuracy: 0.9451 - val_loss: 0.1334 - learning_rate: 0.0010
# Epoch 18/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.8904 - loss: 0.3122 - val_accuracy: 0.9670 - val_loss: 0.1165 - learning_rate: 0.0010
# Epoch 19/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9548 - loss: 0.1829 - val_accuracy: 0.9670 - val_loss: 0.1080 - learning_rate: 0.0010
# Epoch 20/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9442 - loss: 0.2135 - val_accuracy: 0.9670 - val_loss: 0.1081 - learning_rate: 0.0010
# Epoch 21/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9769 - loss: 0.1712 - val_accuracy: 0.9670 - val_loss: 0.1156 - learning_rate: 0.0010
# Epoch 22/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9867 - loss: 0.1576 - val_accuracy: 0.9670 - val_loss: 0.1055 - learning_rate: 5.0000e-04
# Epoch 23/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9114 - loss: 0.2284 - val_accuracy: 0.9780 - val_loss: 0.0938 - learning_rate: 5.0000e-04
# Epoch 24/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9464 - loss: 0.2031 - val_accuracy: 0.9670 - val_loss: 0.0920 - learning_rate: 5.0000e-04
# Epoch 25/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9628 - loss: 0.1539 - val_accuracy: 0.9670 - val_loss: 0.0938 - learning_rate: 5.0000e-04
# Epoch 26/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9482 - loss: 0.1827 - val_accuracy: 0.9670 - val_loss: 0.0947 - learning_rate: 5.0000e-04
# Epoch 27/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9704 - loss: 0.1560 - val_accuracy: 0.9670 - val_loss: 0.0934 - learning_rate: 2.5000e-04
# Epoch 28/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.9298 - loss: 0.1801 - val_accuracy: 0.9670 - val_loss: 0.0910 - learning_rate: 2.5000e-04
# Epoch 29/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9428 - loss: 0.2126 - val_accuracy: 0.9670 - val_loss: 0.0873 - learning_rate: 2.5000e-04
# Epoch 30/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9443 - loss: 0.1623 - val_accuracy: 0.9670 - val_loss: 0.0811 - learning_rate: 2.5000e-04

# %% [markdown]
# Plotting the model

# %% [markdown]
# save history

# %%
with open('model/history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
import matplotlib.pyplot as plt
# Accuracy plot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# %%
model.save('simo_argumented_model.keras')
